# %% [markdown]
# Ahora se tienen las funciones ( Niye i 7 7!
# f(x) = 3x2 + milsO
# Naw
# f(x) = Inx + 7x° + 3.3
# y se desea hallar los puntos de interseccidn, la grafica es:
# En este caso al intentar resolver la ecuaci6n f,(x) — f(x) = 0
# se tiene
# (3x? + e**) — (Inx + 7x? + 3.3) )
# e* — Inx + 3x? 7x3-33 = 0
# que algebraicamente es imposible de resolver o muy dificil.

# %% [markdown]
# ## Métodos cerrados
#
# Antes de iniciar el método de la biseccién, recordaremos dos
# teoremas que garantizan poder hallar una aproximaci6n a la
# solución de $f(x) = 0$.
#
#
# ### Teorema del valor intermedio
# Sea f una función continua en un intervalo $[a, b]$, entonces para
# cada $k$ tal que $f(a) < k < f(b)$, existe al menos un c $ € [a, b] $ tal
# que $f(c) =k$.
#
#
# ## Teorema de Bolzano
# Sea una funcién $f(x)$ continua definida en un intervalo $[a, 5]$,
# entonces si se cumple que $f(a)f(b) < 0$ (con signos opuestos),
# existe un punto c $  € (a, b) $ tal que $f(c) = 0$.
#
# ![image.png](attachment:image.png)

# %%
import numpy as np 

np.sqrt(7)
# Out:
# np.float64(2.6457513110645907)

# %%
x = 2.75

print((x**2) - 7)
# Out:
# 0.5625

# %% [markdown]
# Hasta cuando debo hacer el proceso
# Este proceso se repite hasta que se cumpla una o varias de las
# siguientes condiciones:
# Se realiza un numero maximo de iteraciones N.
#
# $\abs{}$
# |Bn — Aan| < Tol
# donde la tolerancia 7o/ es el valor a partir del cual se considera
# que es despreciable el resultado (To/ ~ 0). Y se toma como la
# aproximaci6n de la raiz a el valor de a* = Cp.

# %% [markdown]
# Determinar una solución para $f(x) = cos(x) - /sqrt{x} $
